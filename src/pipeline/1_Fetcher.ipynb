# %% [markdown]
# # 1 - Config & Import

# %% [markdown]
# ## 1.1 - Config

# %%
# 🔧 config import
import os
from core.config.logger_config import colored_logger
logger = colored_logger()
current_file = os.path.basename(__file__) if '__file__' in globals() else "Notebook"
logger.info(f"Logger initialized ({current_file})")
# Out:
# [2025-10-26 11:18:03] INFO - 726159153.py - Logger initialized (Notebook)

# %% [markdown]
# ## 1.2 - Import

# %%
# 📦 External libs
import plotly.graph_objects as go
import importlib
import ccxt

# 📂 Internal modules
import core.data.fetcher as fetcher

def reload_modules():
    importlib.reload(fetcher)

# %% [markdown]
# # 2 - Level 1: OHLCV

# %% [markdown]
# ## 2.1 - Binance API

# %% [markdown]
# ### Input

# %%
binance = ccxt.binance()
binance.load_markets()
print(binance.symbols)
# Out:
# ['1000000BOB/USDT:USDT', '1000000MOG/USDT:USDT', '1000BONK/USDC:USDC', '1000BONK/USDT:USDT', '1000CAT/BNB', '1000CAT/FDUSD', '1000CAT/TRY', '1000CAT/USDC', '1000CAT/USDT', '1000CAT/USDT:USDT', '1000CHEEMS/USDC', '1000CHEEMS/USDT', '1000CHEEMS/USDT:USDT', '1000FLOKI/USDT:USDT', '1000LUNC/USDT:USDT', '1000PEPE/USDC:USDC', '1000PEPE/USDT:USDT', '1000RATS/USDT:USDT', '1000SATS/FDUSD', '1000SATS/TRY', '1000SATS/USDC', '1000SATS/USDT', '1000SATS/USDT:USDT', '1000SHIB/USDC:USDC', '1000SHIB/USDT:USDT', '1000WHY/USDT:USDT', '1000X/USDT:USDT', '1000XEC/USDT:USDT', '1INCH/BTC', '1INCH/BUSD', '1INCH/USDT', '1INCH/USDT:USDT', '1INCHDOWN/USDT', '1INCHUP/USDT', '1MBABYDOGE/FDUSD', '1MBABYDOGE/TRY', '1MBABYDOGE/USDC', '1MBABYDOGE/USDT', '1MBABYDOGE/USDT:USDT', 'A/BTC', 'A/ETH', 'A/FDUSD', 'A/TRY', 'A/USDC', 'A/USDT', 'A/USDT:USDT', 'AAVE/BKRW', 'AAVE/BNB', 'AAVE/BRL', 'AAVE/BTC', 'AAVE/BUSD', 'AAVE/ETH', 'AAVE/FDUSD', 'AAVE/TRY', 'AAVE/USD:AAVE', 'AAVE/USDC', 'AAVE/USDC:USDC', 'AAVE/USDT', 'AAVE/USDT:USDT', 'AAVEDOWN/USDT', 'AAVEUP/USDT', 'ACA/BTC', 'ACA/BUSD', 'ACA/TRY', 'ACA/USDT', 'ACE/BNB', 'ACE/BTC', 'ACE/FDUSD', 'ACE/TRY', 'ACE/USDT', 'ACE/USDT:USDT', 'ACH/BTC', 'ACH/BUSD', 'ACH/TRY', 'ACH/USDC', 'ACH/USDT', 'ACH/USDT:USDT', 'ACM/BTC', 'ACM/BUSD', 'ACM/TRY', 'ACM/USDT', 'ACT/BRL', 'ACT/EUR', 'ACT/FDUSD', 'ACT/TRY', 'ACT/USDC', 'ACT/USDT', 'ACT/USDT:USDT', 'ACX/FDUSD', 'ACX/TRY', 'ACX/USDC', 'ACX/USDT', 'ACX/USDT:USDT', 'ADA/AUD', 'ADA/BIDR', 'ADA/BKRW', 'ADA/BNB', 'ADA/BRL', 'ADA/BTC', 'ADA/BUSD', 'ADA/ETH', 'ADA/EUR', 'ADA/FDUSD', 'ADA/GBP', 'ADA/JPY', 'ADA/PAX', 'ADA/RUB', 'ADA/TRY', 'ADA/TUSD', 'ADA/USD:ADA', 'ADA/USD:ADA-250926', 'ADA/USDC', 'ADA/USDC:USDC', 'ADA/USDT', 'ADA/USDT:USDT', 'ADADOWN/USDT', 'ADAUP/USDT', 'ADX/BNB', 'ADX/BTC', 'ADX/BUSD', 'ADX/ETH', 'ADX/USDT', 'AE/BNB', 'AE/BTC', 'AE/ETH', 'AERGO/BTC', 'AERGO/BUSD', 'AERGO/USDT', 'AERGO/USDT:USDT', 'AERO/USDT:USDT', 'AEUR/USDT', 'AEVO/BNB', 'AEVO/BTC', 'AEVO/FDUSD', 'AEVO/TRY', 'AEVO/USDT', 'AEVO/USDT:USDT', 'AGI/BNB', 'AGI/BTC', 'AGI/ETH', 'AGIX/BTC', 'AGIX/BUSD', 'AGIX/FDUSD', 'AGIX/TRY', 'AGIX/USDT', 'AGIX/USDT:USDT', 'AGLD/BNB', 'AGLD/BTC', 'AGLD/BUSD', 'AGLD/USDT', 'AGLD/USDT:USDT', 'AGT/USDT:USDT', 'AI/BNB', 'AI/BTC', 'AI/FDUSD', 'AI/TRY', 'AI/TUSD', 'AI/USDT', 'AI/USDT:USDT', 'AI16Z/USDT:USDT', 'AION/BNB', 'AION/BTC', 'AION/BUSD', 'AION/ETH', 'AION/USDT', 'AIOT/USDT:USDT', 'AIXBT/TRY', 'AIXBT/USDC', 'AIXBT/USDT', 'AIXBT/USDT:USDT', 'AKRO/BTC', 'AKRO/BUSD', 'AKRO/USDT', 'AKT/USDT:USDT', 'ALCH/USDT:USDT', 'ALCX/BTC', 'ALCX/BUSD', 'ALCX/USDT', 'ALGO/BIDR', 'ALGO/BNB', 'ALGO/BTC', 'ALGO/BUSD', 'ALGO/ETH', 'ALGO/FDUSD', 'ALGO/PAX', 'ALGO/RUB', 'ALGO/TRY', 'ALGO/TUSD', 'ALGO/USD:ALGO', 'ALGO/USDC', 'ALGO/USDT', 'ALGO/USDT:USDT', 'ALICE/BIDR', 'ALICE/BNB', 'ALICE/BTC', 'ALICE/BUSD', 'ALICE/TRY', 'ALICE/USDT', 'ALICE/USDT:USDT', 'ALPACA/BNB', 'ALPACA/BTC', 'ALPACA/BUSD', 'ALPACA/USDT', 'ALPACA/USDT:USDT', 'ALPHA/BNB', 'ALPHA/BTC', 'ALPHA/BUSD', 'ALPHA/USDT', 'ALPHA/USDT:USDT', 'ALPINE/BTC', 'ALPINE/BUSD', 'ALPINE/EUR', 'ALPINE/TRY', 'ALPINE/USDT', 'ALPINE/USDT:USDT', 'ALT/BNB', 'ALT/BTC', 'ALT/FDUSD', 'ALT/TRY', 'ALT/USDC', 'ALT/USDT', 'ALT/USDT:USDT', 'AMB/BNB', 'AMB/BTC', 'AMB/BUSD', 'AMB/ETH', 'AMB/USDT', 'AMB/USDT:USDT', 'AMP/BNB', 'AMP/BTC', 'AMP/BUSD', 'AMP/TRY', 'AMP/USDT', 'ANC/BNB', 'ANC/BTC', 'ANC/BUSD', 'ANC/USDT', 'ANIME/BNB', 'ANIME/FDUSD', 'ANIME/TRY', 'ANIME/USDC', 'ANIME/USDT', 'ANIME/USDT:USDT', 'ANKR/BNB', 'ANKR/BTC', 'ANKR/BUSD', 'ANKR/PAX', 'ANKR/TRY', 'ANKR/TUSD', 'ANKR/USDC', 'ANKR/USDT', 'ANKR/USDT:USDT', 'ANT/BNB', 'ANT/BTC', 'ANT/BUSD', 'ANT/USDT', 'ANY/BTC', 'ANY/BUSD', 'ANY/USDT', 'APE/AUD', 'APE/BNB', 'APE/BRL', 'APE/BTC', 'APE/BUSD', 'APE/ETH', 'APE/EUR', 'APE/FDUSD', 'APE/GBP', 'APE/TRY', 'APE/USD:APE-240521', 'APE/USDC', 'APE/USDT', 'APE/USDT:USDT', 'API3/BNB', 'API3/BTC', 'API3/BUSD', 'API3/TRY', 'API3/USDC', 'API3/USDT', 'API3/USDT:USDT', 'APPC/BNB', 'APPC/BTC', 'APPC/ETH', 'APT/BRL', 'APT/BTC', 'APT/BUSD', 'APT/ETH', 'APT/EUR', 'APT/FDUSD ...

# %% [markdown]
# **Possible values for Binance on ccxt:**
#
# - `'1m'` — 1 minute
# - `'3m'` — 3 minutes
# - `'5m'` — 5 minutes
# - `'15m'` — 15 minutes
# - `'30m'` — 30 minutes
# - `'1h'` — 1 hour
# - `'2h'` — 2 hours
# - `'4h'` — 4 hours
# - `'6h'` — 6 hours
# - `'8h'` — 8 hours
# - `'12h'` — 12 hours
# - `'1d'` — 1 day
# - `'3d'` — 3 days
# - `'1w'` — 1 week
# - `'1M'` — 1 month

# %%
 #📊 data parameters
symbol = "BTCUSDT"
start_date = "23-06-2025"
end_date = "27-06-2025"
interval = "1m"

# %% [markdown]
# ### Process

# %%
reload_modules()

Fetcher = fetcher.DataFetcher(symbol, start_date, end_date, interval)
Fetcher.get_binance_data_ohlcv()

print(Fetcher.raw_data.head())
print(Fetcher.raw_data.shape)

Fetcher.save_to_csv_ohlcv(directory=os.getcwd())

Fetcher.load_from_csv_ohlcv_binance(directory=os.getcwd())

print(Fetcher.raw_data.head())
print(Fetcher.raw_data.shape)
Fetcher.raw_data.isna().sum()
# Out:
# [2025-06-29 14:56:56] INFO - data_fetcher.py - Logger initialized (data_fetcher.py)
# [2025-06-29 14:56:56] INFO - data_fetcher.py - Starting data fetch for BTCUSDT from 23-06-2025 to 27-06-2025 with interval 1m
# [2025-06-29 14:57:05] INFO - data_fetcher.py - Successfully fetched 6000 candles in total.
# [2025-06-29 14:57:06] INFO - data_fetcher.py - 📁 Data saved to: C:\Users\valer\Desktop\Trading\Trading_Bot\Project\pipeline/BTCUSDT_23-06-2025_27-06-2025_1m_ohlcv.csv
# [2025-06-29 14:57:06] INFO - data_fetcher.py - 📥 Data loaded from: C:\Users\valer\Desktop\Trading\Trading_Bot\Project\pipeline/BTCUSDT_23-06-2025_27-06-2025_1m_ohlcv.csv
#                  time     open     high      low    close   volume
# 0 2025-06-22 22:00:00  99136.0  99547.4  99084.8  99492.7  554.595
# 1 2025-06-22 22:01:00  99492.7  99647.2  99486.3  99591.6  696.955
# 2 2025-06-22 22:02:00  99588.7  99655.4  99526.2  99529.9  440.510
# 3 2025-06-22 22:03:00  99529.9  99694.1  99502.1  99694.1  363.372
# 4 2025-06-22 22:04:00  99694.0  99813.1  99650.0  99781.1  641.497
# (6000, 6)
#                  time     open     high      low    close   volume
# 0 2025-06-22 22:00:00  99136.0  99547.4  99084.8  99492.7  554.595
# 1 2025-06-22 22:01:00  99492.7  99647.2  99486.3  99591.6  696.955
# 2 2025-06-22 22:02:00  99588.7  99655.4  99526.2  99529.9  440.510
# 3 2025-06-22 22:03:00  99529.9  99694.1  99502.1  99694.1  363.372
# 4 2025-06-22 22:04:00  99694.0  99813.1  99650.0  99781.1  641.497
# (6000, 6)
# time      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %% [markdown]
# ### Visualization

# %%
reload_modules()

print("#-----------------------")
print(Fetcher.raw_data.columns)
print("#-----------------------")
print(Fetcher.raw_data.head())
print("#-----------------------")
print(Fetcher.raw_data.shape)
print("#-----------------------")

size = 500
df = Fetcher.raw_data.copy()[-size:]

# Create a candlestick chart using Plotly
fig = go.Figure(data=[
    go.Candlestick(
        x=df['time'],  # Using the timestamp index directly
        open=df['open'],
        high=df['high'],
        low=df['low'],
        close=df['close'],
        name="Candlesticks"
    )
])

# Customize layout
fig.update_layout(
    title=f"{symbol} - Binance - (Last {size} Points)",
    xaxis_title="Time",
    yaxis_title="Price",
    xaxis_rangeslider_visible=False,
    template="plotly_dark",
    height=500,
    width=int(500 * 1.618)
)

# Show the chart
fig.show()
# Out:
# [2025-06-29 14:57:14] INFO - data_fetcher.py - Logger initialized (data_fetcher.py)
# #-----------------------
# Index(['time', 'open', 'high', 'low', 'close', 'volume'], dtype='object')
# #-----------------------
#                  time     open     high      low    close   volume
# 0 2025-06-22 22:00:00  99136.0  99547.4  99084.8  99492.7  554.595
# 1 2025-06-22 22:01:00  99492.7  99647.2  99486.3  99591.6  696.955
# 2 2025-06-22 22:02:00  99588.7  99655.4  99526.2  99529.9  440.510
# 3 2025-06-22 22:03:00  99529.9  99694.1  99502.1  99694.1  363.372
# 4 2025-06-22 22:04:00  99694.0  99813.1  99650.0  99781.1  641.497
# #-----------------------
# (6000, 6)
# #-----------------------
# <div>                            <div id="f43789ae-c06b-41ee-b03f-913acf0896ee" class="plotly-graph-div" style="height:500px; width:809px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
.2,107130.5,107116.3,107134.1,107140.0,107100.1,107041.5,107025.3,107009.8,106996.2,107021.1,107023.4,107038.8,107020.5,107015.8,106999.1,106975.1,106899.9,106949.3,106914.6,106918.2,106930.3,106950.1,106980.5,107034.3,106999.4,106962.7,106912.0,106948.6,106967.4,106961.4,106940.9,106941.0,106923.8,106940.6,106909.2,106908.5,106850.1,106859.3,106857.2,106847.0,106849.6,106860.0,106885.5,106912.9,106877.8,106873.3,106830.0,106833.6,106866.3,106890.9,106918.0,106910.9,106891.1,106886.0,106949.0,107001.5,106994.9,106960.2,106987.5,106992.4,106992.4,106960.4,106936.1,106927.5,106943.0,106887.0,106879.9,106925.8,106982.5,106998.8,106969.6,106942.1,106939.1,106921.9,106890.3,106899.7,106921.1,106887.8,106875.4,106874.0,106856.5,106855.1,106854.1,106871.1,106816.4,106821.3,106895.3,106880.1,106857.7,106870.9,106889.0,106913.7,106888.1,106870.8,106904.3,106929.9,10 ...

# %% [markdown]
# # 3 - Level 2: DOM

# %% [markdown]
# ## 3.1 - Bybit API

# %% [markdown]
# ### Input

# %%
symbol = 'BTCUSDT'
start_date = '2025-06-25'
end_date = "2025-06-27"
interval = '1min'

# %% [markdown]
# | Code | Meaning           | Example   |
# |------|-------------------|-----------|
# | S    | Second            | `30S`     |
# | T    | Minute            | `15T`     |
# | min  | Minute            | `5min`    |
# | H    | Hour              | `1H`      |
# | D    | Day               | `1D`      |
# | B    | Business day      | `1B`      |
# | W    | Week              | `1W`      |
# | M    | Month end         | `1M`      |
# | MS   | Month start       | `1MS`     |
# | Q    | Quarter end       | `1Q`      |
# | QS   | Quarter start     | `1QS`     |
# | A    | Year end          | `1A`      |
# | AS   | Year start        | `1AS`     |
#
# **Multiples are supported:**
# Examples: `5T` = 5 minutes, `10S` = 10 seconds, `3H` = 3 hours, `2D` = 2 days.
#
# **More details:**
# - `S` = second(s)
# - `T` or `min` = minute(s)
# - `H` = hour(s)
# - `D` = day(s)
# - `B` = business day(s)
# - `W` = week(s) (week ends on Sunday by default)
# - `M` = month(s) (calendar end)
# - `MS` = month(s) (calendar start)
# - `Q`, `QS` = quarter(s) (calendar end/start)
# - `A`, `AS` = year(s) (calendar end/start)

# %% [markdown]
# ### Process

# %%
reload_modules()

Fetcher = fetcher.DataFetcher(symbol, start_date, end_date, interval)
Fetcher.get_bybit_data_dom()

print(Fetcher.raw_data.head())
print(Fetcher.raw_data.shape)

Fetcher.dom_to_ohlcv()

Fetcher.save_to_csv_dom(directory=os.getcwd())

Fetcher.load_from_csv_dom_bybit(directory=os.getcwd())

print(Fetcher.raw_data.head())
print(Fetcher.raw_data.shape)
Fetcher.raw_data.isna().sum()
# Out:
# [2025-06-29 15:16:51] INFO - fetcher.py - Logger initialized (fetcher.py)
# [2025-06-29 15:16:51] INFO - fetcher.py - Trying: https://public.bybit.com/spot/BTCUSDT/BTCUSDT_2025-06-25.csv.gz
# [2025-06-29 15:16:58] INFO - fetcher.py - Downloaded: BTCUSDT_2025-06-25.csv.gz
# [2025-06-29 15:16:59] INFO - fetcher.py - Trying: https://public.bybit.com/spot/BTCUSDT/BTCUSDT_2025-06-26.csv.gz
# [2025-06-29 15:17:08] INFO - fetcher.py - Downloaded: BTCUSDT_2025-06-26.csv.gz
# [2025-06-29 15:17:09] INFO - fetcher.py - Trying: https://public.bybit.com/spot/BTCUSDT/BTCUSDT_2025-06-27.csv.gz
# [2025-06-29 15:17:13] INFO - fetcher.py - Downloaded: BTCUSDT_2025-06-27.csv.gz
# [2025-06-29 15:17:14] INFO - fetcher.py - Shape: (1827435, 4)
#       price    volume side                    time
# 0  106087.9  0.000062  buy 2025-06-25 00:00:00.116
# 1  106087.9  0.002766  buy 2025-06-25 00:00:01.258
# 2  106087.9  0.019994  buy 2025-06-25 00:00:01.258
# 3  106087.9  0.000006  buy 2025-06-25 00:00:01.270
# 4  106087.9  0.002824  buy 2025-06-25 00:00:01.270
# (1827435, 4)
# [2025-06-29 15:17:15] INFO - fetcher.py - 📁 Data saved to: C:\Users\valer\Desktop\Trading\Trading_Bot\Project\pipeline/BTCUSDT_2025-06-25_2025-06-27_1min_dom.csv
# [2025-06-29 15:17:15] ERROR - fetcher.py - Missing columns in CSV: ['volume']
#                  time      open      high       low     close  ask_size  \
# 0 2025-06-25 00:00:00  106087.9  106130.0  106072.0  106072.1  3.270138
# 1 2025-06-25 00:01:00  106072.0  106097.2  106063.0  106071.8  1.049900
# 2 2025-06-25 00:02:00  106071.9  106071.9  106022.8  106022.9  2.298718
# 3 2025-06-25 00:03:00  106022.8  106079.7  106015.3  106065.8  1.608724
# 4 2025-06-25 00:04:00  106065.8  106083.0  106041.0  106041.0  1.684092
#
#    bid_size
# 0  4.575117
# 1  0.560414
# 2  0.002983
# 3  2.392039
# 4  1.465795
# (4320, 7)
# time        0
# open        0
# high        0
# low         0
# close       0
# ask_size    0
# bid_size    0
# dtype: int64

# %% [markdown]
# ### Visualization

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

size = 500
df = Fetcher.raw_data.copy()[-size:]

fig = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.03,
    row_heights=[0.7, 0.3],
    subplot_titles=("Candlestick Chart", "Bid/Ask Volume")
)

# Candlestick on row 1
fig.add_trace(go.Candlestick(
    x=df['time'],
    open=df['open'],
    high=df['high'],
    low=df['low'],
    close=df['close'],
    name="Candlesticks"
), row=1, col=1)

# Bid volume (row 2, green)
fig.add_trace(go.Bar(
    x=df['time'],
    y=df['bid_size'],
    name="Bid Volume",
    marker_color='lime',
    opacity=0.6
), row=2, col=1)

# Ask volume (row 2, red)
fig.add_trace(go.Bar(
    x=df['time'],
    y=df['ask_size'],
    name="Ask Volume",
    marker_color='red',
    opacity=0.6
), row=2, col=1)

# Remove range slider and update layout
fig.update_layout(
    title=f"{symbol} - Binance - (Last {size} Points)",
    xaxis=dict(
        rangeslider=dict(visible=False)  # No interval bar at the bottom
    ),
    yaxis_title="Price",
    yaxis2_title="Volume",
    template="plotly_dark",
    height=700,
    width=int(500 * 1.618),
    barmode='overlay',  # Overlay bid/ask bars
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=
106875.8,106895.2,106885.7,106891.5,106919.1,106920.8,106947.0,106979.3,107013.1,106997.9,106937.2,106971.6,106933.5,106809.7,106820.2,106874.1,106893.7,106878.7,106874.2,106939.9,106994.2,107036.1,107046.4,107041.2,107031.7,107094.1,107094.5,107073.0,107030.0,107095.9,107077.5,107095.7,107083.5,107061.1,107013.8,107030.1,107030.1,107046.2,107030.9,107034.0,106997.5,107020.6,107036.6,107036.6,107043.7,107020.4,107094.8,107093.9,107104.2,107012.1,107019.5,107021.2,107072.9,107064.6,107057.1,107091.6,107094.8,107105.7,107105.7,107115.0,107096.2,107100.5,107090.3,107116.2,107126.0,107136.7,107115.1,107095.5,107070.0,107006.1,107056.5,107116.8,107114.2,107129.2,107132.8,107149.9,107183.1,107137.7,107158.1,107165.0,107175.3,107221.8,107180.8,107203.1,107213.2,107194.6,107186.2,107207.5,107174.8,107193.6,107204.8,107167.8,107149.5,107108.5,107103.1,107103.0,107096.3,107094.4,107056.2,107098.4,107178.8,107169.8,107173.9,107173.9,107204.5,107225.2,107196.5,107111.3,107231.7,107256.6,107211.0,107157.0,107185.9,107148.6,107084.7,107145.2,107167.7,107130.7,107104.9,107136.7,107136.2,107136.2,107150.6,107153.1,107175.5,107149.4,107148.4,107119.5,107115.8,107064.7,107090.3,107086.3,107086.3,107050.0,107105.6,107109.1,107105.2,107105.1,10 ...

# %% [markdown]
# ## 3.2 Interactive Broker API

# %% [markdown]
# ### Input

# %%
 #📊 data parameters
symbol = "EURUSD"
start_date = "12-06-2025"
end_date = "13-06-2025"
interval = "1s"
interval ="d"

# %% [markdown]
# ### Process

# %%
from ib_insync import *
from datetime import datetime, timedelta
import pandas as pd
import asyncio
import random

ib = IB()

async def get_IB_FX_Data(symbol: str, start_date: datetime, end_date: datetime) -> pd.DataFrame:
    await ib.connectAsync('127.0.0.1', 4002, clientId=random.randint(100, 999))

    contract = Forex(symbol)
    data = []

    slice_duration = timedelta(minutes=1)
    total_requests = int((end_date - start_date) / slice_duration)
    print(f"Total requests to perform: {total_requests}")

    current_start = start_date

    for i in range(total_requests):
        current_end = min(current_start + slice_duration, end_date)

        try:
            ticks = await ib.reqHistoricalTicksAsync(
                contract,
                startDateTime=current_start,
                endDateTime=current_end,
                numberOfTicks=1000,
                whatToShow='BID_ASK',
                useRth=False
            )

            for tick in ticks:
                data.append({
                    'time': tick.time,
                    'bid': tick.priceBid,
                    'ask': tick.priceAsk,
                    'bidSize': tick.sizeBid,
                    'askSize': tick.sizeAsk
                })

        except Exception as e:
            print(f"Error fetching {symbol} from {current_start} to {current_end}: {e}")

        print(f"{i+1}/{total_requests}")
        current_start = current_end
        await asyncio.sleep(0.3)  # avoid pacing violation

    ib.disconnect()

    df = pd.DataFrame(data)
    return df


import nest_asyncio
nest_asyncio.apply()

start = datetime.utcnow() - timedelta(hours=1)
end = datetime.utcnow()

df = asyncio.run(get_IB_FX_Data(symbol, start, end))
print(df.head())
